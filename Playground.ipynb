# %%
import pandas as pd
import math

# %%
df = pd.read_csv('felony_data.csv')

# %%
coord = (991621.243, 218006.212)
radius = 200
x, y = coord
df[df['X_COORD_CD'].between(x - radius, x + radius, inclusive=False) & df['Y_COORD_CD'].between(y - radius, y + radius, inclusive=False)]
# Out:
#         CMPLNT_FR_DT LAW_CAT_CD  X_COORD_CD  Y_COORD_CD
# 74022     06/18/2018     FELONY    991789.0    217838.0
# 173659    09/26/2017     FELONY    991789.0    217838.0
# 221352    06/01/2017     FELONY    991789.0    217838.0
# 262421    02/10/2017     FELONY    991789.0    217838.0
# 328000    08/31/2016     FELONY    991789.0    217838.0
# 364171    06/08/2016     FELONY    991789.0    217838.0
# 364394    06/08/2016     FELONY    991553.0    217831.0
# 418418    01/22/2016     FELONY    991789.0    217838.0
# 450763    11/05/2015     FELONY    991789.0    217838.0
# 537420    04/20/2015     FELONY    991789.0    217838.0
# 644378    07/27/2014     FELONY    991553.0    217831.0
# 656314    07/01/2014     FELONY    991789.0    217838.0
# 747380    11/19/2013     FELONY    991789.0    217838.0
# 833047    05/09/2013     FELONY    991789.0    217838.0
# 889161    12/17/2012     FELONY    991789.0    217838.0
# 911160    10/24/2012     FELONY    991789.0    217838.0
# ...
